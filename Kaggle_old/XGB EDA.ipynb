# %%
# load packages

import numpy as np
import pandas as pd

# %%
# load data 
train = pd.read_csv('train.csv', parse_dates=['timestamp'])   # so we can merge on the dates later (timestamp is a column)
test = pd.read_csv('test.csv', parse_dates=['timestamp'])
macro = pd.read_csv('macro.csv', parse_dates=['timestamp'])

# Merge macro data with training and test sets
train = pd.merge(train, macro, how='left', on = 'timestamp')  # left so all training rows are paired with a macro row
test = pd.merge(test, macro, how='left', on = 'timestamp')

# %%
train.head()   # both have 390 columns
test.head()
# Out:
#       id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0  30474 2015-07-01     39.0     20.7      2          9         1      1998.0
# 1  30475 2015-07-01     79.2      NaN      8         17         1         0.0
# 2  30476 2015-07-01     40.5     25.1      3          5         2      1960.0
# 3  30477 2015-07-01     62.8     36.0     17         17         1      2016.0
# 4  30478 2015-07-01     40.0     40.0     17         17         1         0.0
#
#    num_room  kitch_sq         ...          provision_retail_space_modern_sqm  \
# 0         1       8.9         ...                                        NaN
# 1         3       1.0         ...                                        NaN
# 2         2       4.8         ...                                        NaN
# 3         2      62.8         ...                                        NaN
# 4         1       1.0         ...                                        NaN
#
#   turnover_catering_per_cap theaters_viewers_per_1000_cap  \
# 0                   10805.0                           NaN
# 1                   10805.0                           NaN
# 2                   10805.0                           NaN
# 3                   10805.0                           NaN
# 4                   10805.0                           NaN
#
#    seats_theather_rfmin_per_100000_cap  museum_visitis_per_100_cap  \
# 0                              0.45888                         NaN
# 1                              0.45888                         NaN
# 2                              0.45888                         NaN
# 3                              0.45888                         NaN
# 4                              0.45888                         NaN
#
#    bandwidth_sports  population_reg_sports_share  students_reg_sports_share  \
# 0          463938.0                          NaN                        NaN
# 1          463938.0                          NaN                        NaN
# 2          463938.0                          NaN                        NaN
# 3          463938.0                          NaN                        NaN
# 4          463938.0                          NaN                        NaN
#
#    apartment_build  apartment_fund_sqm
# 0              NaN            234576.9
# 1              NaN            234576.9
# 2              NaN            234576.9
# 3              NaN            234576.9
# 4              NaN            234576.9
#
# [5 rows x 390 columns]

# %%
# Feature engineering

from sklearn.preprocessing import LabelEncoder

def encode_object_features(train, test):
    train = pd.DataFrame(train)
    test = pd.DataFrame(test)
    cols_to_encode = train.select_dtypes(include = ['object'], 
                                         exclude = ['int64', 'float64']).columns
    for col in cols_to_encode:
        le = LabelEncoder()
        le.fit(list(train[col].values.astype('str')) + 
              list(test[col].values.astype('str')))
        train[col] = le.transform(list(train[col].values.astype('str')))
        test[col] = le.transform(list(train[col].values.astype('str')))
    return train, test

# %%
LabelEncoder.transform?

# %%
train, test = encode_object_features(train, test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-38902b5e6561> in <module>()
# ----> 1 train, test = encode_object_features(train, test)
#
# <ipython-input-18-6030ee0de533> in encode_object_features(train, test)
#      13               list(test[col].values.astype('str')))
#      14         train[col] = le.transform(list(train[col].values.astype('str')))
# ---> 15         test[col] = le.transform(list(train[col].values.astype('str')))
#      16     return train, test
#
# C:\Users\skick\Anaconda2\lib\site-packages\sklearn\preprocessing\label.pyc in transform(self, y)
#     151         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     152             diff = np.setdiff1d(classes, self.classes_)
# --> 153             raise ValueError("y contains new labels: %s" % str(diff))
#     154         return np.searchsorted(self.classes_, y)
#     155
#
# ValueError: y contains new labels: ['0' '1']

# %%
#Load Data
train_raw = pd.read_csv('train.csv', parse_dates=['timestamp'])
test_raw = pd.read_csv('test.csv', parse_dates=['timestamp'])
macro_raw = pd.read_csv('macro.csv', parse_dates=['timestamp'])

# %%
#Join macro-economic data
train_full = pd.merge(train_raw, macro_raw, how='left', on='timestamp')
test_full = pd.merge(test_raw, macro_raw, how='left', on='timestamp')

# %%
from sklearn.preprocessing import LabelEncoder

def encode_object_features(train, test):
    '''(DataFrame, DataFrame) -> DataFrame, DataFrame
    
    Will encode each non-numerical column.
    '''
    train = pd.DataFrame(train)
    test = pd.DataFrame(test)
    cols_to_encode = train.select_dtypes(include=['object'], exclude=['int64', 'float64']).columns
    for col in cols_to_encode:
        le = LabelEncoder()
        #Fit encoder
        le.fit(list(train[col].values.astype('str')) + list(test[col].values.astype('str')))
        #Transform
        train[col] = le.transform(list(train[col].values.astype('str')))
        test[col] = le.transform(list(test[col].values.astype('str')))
    
    return train, test

# %%
train_df, test_df = encode_object_features(train_full, test_full)

# %% [markdown]
# # add new features

# %%
def add_date_features(df):   # make it a function so we don't have to do it twice for both sets
    #convert to datetime to make easier
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    #extract features
    df['month'] = df['timestamp'].dt.month 
    df['day'] = df['timestamp'].dt.day
    df['year'] = df['timestamp'].dt.year
    
    #month-year
    month_year = df['timestamp'].dt.month + df['timestamp'].dt.year*100 
        # a vector is created like yyyymm
    month_year_map = month_year.value_counts().to_dict()
        # a dictionary with key = yyyymm and value = the number f times the monthyear appears in the vector
    df['month_year'] = month_year.map(month_year_map)
        # for some reason gives the number of times the monthyear is repeated????
    print df['month_year'] 
    
    #week-year
    week_year = df['timestamp'].dt.weekofyear + df['timestamp'].dt.year * 100
    week_year_map = week_year.value_counts().to_dict()
    df['week_year'] = week_year.map(week_year_map)
    #df.drop('timestamp', axis=1, inplace=True)
    
    
    return df

# %%
t = add_date_features(train_df)
# Out:
# 0          3
# 1          3
# 2          3
# 3         39
# 4         39
# 5         39
# 6         39
# 7         39
# 8         39
# 9         39
# 10        39
# 11        39
# 12        39
# 13        39
# 14        39
# 15        39
# 16        39
# 17        39
# 18        39
# 19        39
# 20        39
# 21        39
# 22        39
# 23        39
# 24        39
# 25        39
# 26        39
# 27        39
# 28        39
# 29        39
#         ...
# 30441    413
# 30442    413
# 30443    413
# 30444    413
# 30445    413
# 30446    413
# 30447    413
# 30448    413
# 30449    413
# 30450    413
# 30451    413
# 30452    413
# 30453    413
# 30454    413
# 30455    413
# 30456    413
# 30457    413
# 30458    413
# 30459    413
# 30460    413
# 30461    413
# 30462    413
# 30463    413
# 30464    413
# 30465    413
# 30466    413
# 30467    413
# 30468    413
# 30469    413
# 30470    413
# Name: month_year, Length: 30471, dtype: int64

# %%
t.head()
# Out:
#    id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1 2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2 2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3 2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4 2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5 2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      bandwidth_sports  \
# 0       NaN       NaN    ...              269768.0
# 1       NaN       NaN    ...              269768.0
# 2       NaN       NaN    ...              269768.0
# 3       NaN       NaN    ...              269768.0
# 4       NaN       NaN    ...              269768.0
#
#    population_reg_sports_share  students_reg_sports_share  apartment_build  \
# 0                        22.37                      64.12          23587.0
# 1                        22.37                      64.12          23587.0
# 2                        22.37                      64.12          23587.0
# 3                        22.37                      64.12          23587.0
# 4                        22.37                      64.12          23587.0
#
#    apartment_fund_sqm  month  day  year  month_year  week_year
# 0            230310.0      8   20  2011           3          1
# 1            230310.0      8   23  2011           3          2
# 2            230310.0      8   27  2011           3          2
# 3            230310.0      9    1  2011          39          1
# 4            230310.0      9    5  2011          39          5
#
# [5 rows x 396 columns]
